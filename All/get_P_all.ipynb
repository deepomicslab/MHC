# %%
import pysam
from pysam import VariantFile as vcf
import operator
from math import log2
import pandas as pd
from pandas import DataFrame as dataframe
import matplotlib.pyplot as plt
import numpy as np

import  os
import os.path

# %%
class CalProb:
    def __init__(self,vcf_in):
        self.vcf_in=vcf_in
        self.result=dict()
    
    def calPaAndPb(self):
        for rec in self.vcf_in.fetch():
            count_0=0
            count_1=0
            GTs=[]
            samplelist=list((self.vcf_in.header.samples))
            for samplename in samplelist:
                t1=rec.samples[samplename]['GT']
                if len(t1)==2:
                    GTs.append(t1)
                
            #print(GTs)
            list1=[x[0] for x in GTs]
            list2=[x[1] for x in GTs]
            for m in list1:
                if m==0:
                    count_0+=1
                else:
                    count_1+=1
            for n in list2:
                if n==0:
                    count_0+=1
                else:
                    count_1+=1
            p0=count_0/(2*len(samplelist))
            p1=count_1/(2*len(samplelist))
            p0=0.2+0.8*p0
            p1=0.2+0.8*p1
            arr=[]
            arr.append(p0)
            arr.append(p1)
            self.result[rec.pos]=arr
    
    def calPAB(self):     
        for rec in self.vcf_in.fetch():
            count_01=0
            count_10=0
            samplelist=list((self.vcf_in.header.samples))
            for samplename in samplelist:
                t1=rec.samples[samplename]['GT']
                if(operator.eq(t1,(0,1))):
                    count_01+=1
                if(operator.eq(t1,(1,0))):
                    count_10+=1
            num=(count_01+count_10)/len(samplelist)
            self.result[rec.pos].append(num)

    def calP(self):
        positions=list(self.result.keys())
        for position in positions:
            arr=self.result[position]
            if arr[2]==0:
                cal=0
            else:
                # if arr[0]*arr[1]==0:
                #     cal=arr[2]*log2(arr[2]/(1e-10))
             
                cal=arr[2]*log2(arr[2]/(arr[0]*arr[1]))
            
            self.result[position].append(cal)
    def __runProb__(self):
        self.calPaAndPb()
        self.calPAB()
        self.calP()
        
    def __getResult__(self):
        return self.result
    
    def df_pos_prob(self,pos_prob_csvname):
        positions=list(self.result.keys())
        column_names=['PA','PB','PAB','P']
        df=dataframe(index=positions,columns=column_names)
        for i in range(len(positions)):
            a=self.result[positions[i]]
            df.iloc[i][0]=a[0]
            df.iloc[i][1]=a[1]
            df.iloc[i][2]=a[2]
            df.iloc[i][3]=a[3]
        df.to_csv("../csvfiles/pos"+pos_prob_csvname+".csv")
        return df
    
    def df_index_prob(self,index_prob_csvname):
        row_names=list(self.result.keys())
        PAs=[]
        PBs=[]
        PABs=[]
        Ps=[]
        for x in row_names:
            PAs.append(self.result[x][0])
            PBs.append(self.result[x][1])
            PABs.append(self.result[x][2])
            Ps.append(self.result[x][3])
        dictforDF=dict()
        dictforDF['PA']=PAs
        dictforDF['PB']=PBs
        dictforDF['PAB']=PABs
        dictforDF['P']=Ps
        df_index=dataframe(dictforDF)
        df_index.to_csv("../csvfiles/index"+index_prob_csvname+".csv")
        return df_index

    # def Graph_pos_prob(self,df,pos_probgraphname):
    #     x_values1=np.array(df.index)
    #     y_values1=np.array(df["P"])
    #     plt.scatter(x_values1, y_values1,s=1)
    #     plt.title("Positions and Probability")
    #     plt.xlabel("Position")
    #     plt.ylabel("Probability")
    #     plt.rcParams["figure.figsize"] = (20,5)
    #     plt.savefig("../graphs/"+pos_probgraphname+".jpg")

    # def Graph_index_prob(self,df,index_prob_graphname):
    #     x_values2 = np.array(df.index)
    #     y_values2 = np.array(df["P"])
    #     plt.scatter(x_values2, y_values2, s=1)
    #     plt.title("Index and Probability")
    #     plt.xlabel("Index")
    #     plt.ylabel("Probability")
    #     plt.rcParams["figure.figsize"] = (20,5)
    #     plt.savefig("../graphs/"+index_prob_graphname+".jpg")

# %%
foldernames=[]
foldernames.append('split_chrX')
for i in range(1,23):
    foldernames.append('split_chr'+str(i))
# for i in range(7,10):
#     foldernames.append('split_chr'+str(i))
foldernames
# Out:
# ['split_chrX',
#  'split_chr1',
#  'split_chr2',
#  'split_chr3',
#  'split_chr4',
#  'split_chr5',
#  'split_chr6',
#  'split_chr7',
#  'split_chr8',
#  'split_chr9',
#  'split_chr10',
#  'split_chr11',
#  'split_chr12',
#  'split_chr13',
#  'split_chr14',
#  'split_chr15',
#  'split_chr16',
#  'split_chr17',
#  'split_chr18',
#  'split_chr19',
#  'split_chr20',
#  'split_chr21',
#  'split_chr22']

# %%
def ifExistCSVFile(filename):
    filepath='../csvfiles/'
    files=os.listdir(filepath)
    if filename in files:
        return True
    else:
        return False

# %%
for foldername in foldernames:
    for curDir, dirs, files in os.walk(top="../"+foldername+"/"):
        for file in files:
            if file.endswith(".vcf.gz"):
                path=os.path.join(curDir,file)
                print(path)
                fileprefix=file[:file.index(".")]
                print(foldername+"_"+fileprefix)
                pos_prob_name="pos_prob_"+foldername+"_"+fileprefix
                index_prob_name="index_prob_"+foldername+"_"+fileprefix
                csv_pos_prob_name=pos_prob_name+".csv"
                csv_index_prob_name=index_prob_name+".csv"
                if ifExistCSVFile(csv_pos_prob_name or csv_index_prob_name):
                    continue
                else:
                    vcf_in=vcf(path)
                    testclass=CalProb(vcf_in=vcf_in)
                    testclass.__runProb__()
                    df_pos_prob=testclass.df_pos_prob(pos_prob_csvname=pos_prob_name)
                    # testclass.Graph_pos_prob(df=df_pos_prob,pos_probgraphname=pos_prob_name)
                    df_index_prob=testclass.df_index_prob(index_prob_csvname=index_prob_name)
                    # testclass.Graph_index_prob(df=df_index_prob,index_prob_graphname=index_prob_name)
# Out:
# ../split_chrX/xak.vcf.gz
# split_chrX_xak
# ../split_chrX/xaa.vcf.gz
# split_chrX_xaa
# ../split_chrX/xab.vcf.gz
# split_chrX_xab
# ../split_chrX/xac.vcf.gz
# split_chrX_xac
# ../split_chrX/xad.vcf.gz
# split_chrX_xad
# ../split_chrX/xae.vcf.gz
# split_chrX_xae
# ../split_chrX/xaf.vcf.gz
# split_chrX_xaf
# ../split_chrX/xag.vcf.gz
# split_chrX_xag
# ../split_chrX/xah.vcf.gz
# split_chrX_xah
# ../split_chrX/xai.vcf.gz
# split_chrX_xai
# ../split_chrX/xaj.vcf.gz
# split_chrX_xaj
# ../split_chrX/xal.vcf.gz
# split_chrX_xal
# ../split_chrX/xam.vcf.gz
# split_chrX_xam
# ../split_chrX/xan.vcf.gz
# split_chrX_xan
# ../split_chrX/xao.vcf.gz
# split_chrX_xao
# ../split_chrX/xap.vcf.gz
# split_chrX_xap
# ../split_chrX/xaq.vcf.gz
# split_chrX_xaq
# ../split_chrX/xar.vcf.gz
# split_chrX_xar
# ../split_chrX/xas.vcf.gz
# split_chrX_xas
# ../split_chrX/xat.vcf.gz
# split_chrX_xat
# ../split_chrX/xau.vcf.gz
# split_chrX_xau
# ../split_chrX/xav.vcf.gz
# split_chrX_xav
# ../split_chrX/xaw.vcf.gz
# split_chrX_xaw
# ../split_chrX/xax.vcf.gz
# split_chrX_xax
# ../split_chrX/xay.vcf.gz
# split_chrX_xay
# ../split_chr1/xak.vcf.gz
# split_chr1_xak
# ../split_chr1/xaa.vcf.gz
# split_chr1_xaa
# ../split_chr1/xab.vcf.gz
# split_chr1_xab
# ../split_chr1/xac.vcf.gz
# split_chr1_xac
# ../split_chr1/xad.vcf.gz
# split_chr1_xad
# ../split_chr1/xae.vcf.gz
# split_chr1_xae
# ../split_chr1/xaf.vcf.gz
# split_chr1_xaf
# ../split_chr1/xag.vcf.gz
# split_chr1_xag
# ../split_chr1/xah.vcf.gz
# split_chr1_xah
# ../split_chr1/xai.vcf.gz
# split_chr1_xai
# ../split_chr1/xaj.vcf.gz
# split_chr1_xaj
# ../split_chr1/xaw.vcf.gz
# split_chr1_xaw
# ../split_chr1/xax.vcf.gz
# split_chr1_xax
# ../split_chr1/xay.vcf.gz
# split_chr1_xay
# ../split_chr1/xaz.vcf.gz
# split_chr1_xaz
# ../split_chr1/xba.vcf.gz
# split_chr1_xba
# ../split_chr1/xbb.vcf.gz
# split_chr1_xbb
# ../split_chr1/xbc.vcf.gz
# split_chr1_xbc
# ../split_chr1/xbd.vcf.gz
# split_chr1_xbd
# ../split_chr1/xbe.vcf.gz
# split_chr1_xbe
# ../split_chr1/xbf.vcf.gz
# split_chr1_xbf
# ../split_chr1/xbg.vcf.gz
# split_chr1_xbg
# ../split_chr1/xal.vcf.gz
# split_chr1_xal
# ../split_chr1/xam.vcf.gz
# split_chr1_xam
# ../split_chr1/xan.vcf.gz
# split_chr1_xan
# ../split_chr1/xao.vcf.gz
# split_chr1_xao
# ../split_chr1/xap.vcf.gz
# split_chr1_xap
# ../split_chr1/xaq.vcf.gz
# split_chr1_xaq
# ../split_chr1/xar.vcf.gz
# split_chr1_xar
# ../split_chr1/xas.vcf.gz
# split_chr1_xas
# ../split_chr1/xat.vcf.gz
# split_chr1_xat
# ../split_chr1/xau.vcf.gz
# split_chr1_xau
# ../split_chr1/xav.vcf.gz
# split_chr1_xav
# ../split_chr1/xbh.vcf.gz
# split_chr1_xbh
# ../split_chr1/xbi.vcf.gz
# split_chr1_xbi
# ../split_chr1/xbj.vcf.gz
# split_chr1_xbj
# ../split_chr1/xbk.vcf.gz
# split_chr1_xbk
# ../split_chr1/xbl.vcf.gz
# split_chr1_xbl
# ../split_chr1/xbm.vcf.gz
# split_chr1_xbm
# ../split_chr1/xbn.vcf.gz
# split_chr1_xbn
# ../split_chr1/xbo.vcf.gz
# split_chr1_xbo
# ../split_chr1/xbp.vcf.gz
# split_chr1_xbp
# ../split_chr1/xbq.vcf.gz
# split_chr1_xbq
# ../split_chr1/xbr.vcf.gz
# split_chr1_xbr
# ../split_chr1/xbs.vcf.gz
# split_chr1_xbs
# ../split_chr1/xbt.vcf.gz
# split_chr1_xbt
# ../split_chr1/xbu.vcf.gz
# split_chr1_xbu
# ../split_chr1/xbv.vcf.gz
# split_chr1_xbv
# ../split_chr1/xbw.vcf.gz
# split_chr1_xbw
# ../split_chr1/xbx.vcf.gz
# split_chr1_xbx
# ../split_chr1/xby.vcf.gz
# split_chr1_xby
# ../split_chr2/xak.vcf.gz
# split_chr2_xak
# ../split_chr2/xaa.vcf.gz
# split_chr2_xaa
# ../split_chr2/xab.vcf.gz
# split_chr2_xab
# ../split_chr2/xac.vcf.gz
# split_chr2_xac
# ../split_chr2/xad.vcf.gz
# split_chr2_xad
# ../split_chr2/xae.vcf.gz
# split_chr2_xae
# ../split_chr2/xaf.vcf.gz
# split_chr2_xaf
# ../split_chr2/xag.vcf.gz
# split_chr2_xag
# ../split_chr2/xah.vcf.gz
# split_chr2_xah
# ../split_chr2/xai.vcf.gz
# split_chr2_xai
# ../split_chr2/xaj.vcf.gz
# split_chr2_xaj
# ../split_chr2/xaw.vcf.gz
# split_chr2_xaw
# ../split_chr2/xax.vcf.gz
# split_chr2_xax
# ../split_chr2/xay.vcf.gz
# split_chr2_xay
# ../split_chr2/xaz.vcf.gz
# split_chr2_xaz
# ../split_chr2/xba.vcf.gz
# split_chr2_xba
# ../split_chr2/xbb.vcf.gz
# split_chr2_xbb
# ../split_chr2/xbc.vcf.gz
# split_chr2_xbc
# ../split_chr2/xbd.vcf.gz
# split_chr2_xbd
# ../split_chr2/xbe.vcf.gz
# split_chr2_xbe
# ../split_chr2/xbf.vcf.gz
# split_chr2_xbf
# ../split_chr2/xbg.vcf.gz
# split_chr2_xbg
# ../split_chr2/xal.vcf.gz
# split_chr2_xal
# ../split_chr2/xam.vcf.gz
# split_chr2_xam
# ../split_chr2/xan.vcf.gz
# split_chr2_xan
# ../split_chr2/xao.vcf.gz
# split_chr2_xao
# ../split_chr2/xap.vcf.gz
# split_chr2_xap
# ../split_chr2/xaq.vcf.gz
# split_chr2_xaq
# ../split_chr2/xar.vcf.gz
# split_chr2_xar
# ../split_chr2/xas.vcf.gz
# split_chr2_xas
# ../split_chr2/xat.vcf.gz
# split_chr2_xat
# ../split_chr2/xau.vcf.gz
# split_chr2_xau
# ../split_chr2/xav.vcf.gz
# split_chr2_xav
# ../split_chr2/xbh.vcf.gz
# split_chr2_xbh
# ../split_chr2/xbi.vcf.gz
# split_chr2_xbi
# ../split_chr2/xbj.vcf.gz
# split_chr2_xbj
# ../split_chr2/xbk.vcf.gz
# split_chr2_xbk
# ../split_chr2/xbl.vcf.gz
# split_chr2_xbl
# ../split_chr2/xbm.vcf.gz
# split_chr2_xbm
# ../split_chr2/xbn.vcf.gz
# split_chr2_xbn
# ../split_chr2/xbo.vcf.gz
# split_chr2_xbo
# ../split_chr2/xbp.vcf.gz
# split_chr2_xbp
# ../split_chr2/xbq.vcf.gz
# split_chr2_xbq
# ../split_chr2/xbr.vcf.gz
# split_chr2_xbr
# ../split_chr2/xbs.vcf.gz
# split_chr2_xbs
# ../split_chr2/xbt.vcf.gz
# split_chr2_xbt
# ../split_chr2/xbu.vcf.gz
# split_chr2_xbu
# ../split_chr2/xbv.vcf.gz
# split_chr2_xbv
# ../split_chr2/xbw.vcf.gz
# split_chr2_xbw
# ../split_chr2/xbx.vcf.gz
# split_chr2_xbx
# ../split_chr2/xby.vcf.gz
# split_chr2_xby
# ../split_chr2/xbz.vcf.gz
# split_chr2_xbz
# ../split_chr2/xca.vcf.gz
# split_chr2_xca
# ../split_chr3/xaa.vcf.gz
# split_chr3_xaa
# ../split_chr3/xab.vcf.gz
# split_chr3_xab
# ../split_chr3/xac.vcf.gz
# split_chr3_xac
# ../split_chr3/xad.vcf.gz
# split_chr3_xad
# ../split_chr3/xae.vcf.gz
# split_chr3_xae
# ../split_chr3/xaf.vcf.gz
# split_chr3_xaf
# ../split_chr3/xag.vcf.gz
# split_chr3_xag
# ../split_chr3/xah.vcf.gz
# split_chr3_xah
# ../split_chr3/xai.vcf.gz
# split_chr3_xai
# ../split_chr3/xaj.vcf.gz
# split_chr3_xaj
# ../split_chr3/xav.vcf.gz
# split_chr3_xav
# ../split_chr3/xaw.vcf.gz
# split_chr3_xaw
# ../split_chr3/xax.vcf.gz
# split_chr3_xax
# ../split_chr3/xay.vcf.gz
# split_chr3_xay
# ../split_chr3/xaz.vcf.gz
# split_chr3_xaz
# ../split_chr3/xba.vcf.gz
# split_chr3_xba
# ../split_chr3/xbb.vcf.gz
# split_chr3_xbb
# ../split_chr3/xbc.vcf.gz
# split_chr3_xbc
# ../split_chr3/xbd.vcf.gz
# split_chr3_xbd
# ../split_chr3/xbe.vcf.gz
# split_chr3_xbe
# ../split_chr3/xbf.vcf.gz
# split_chr3_xbf
# ../split_chr3/xak.vcf.gz
# split_chr3_xak
# ../split_chr3/xal.vcf.gz
# split_chr3_xal
# ../split_chr3/xam.vcf.gz
# split_chr3_xam
# ../split_chr3/xan.vcf.gz
# split_chr3_xan
# ../split_chr3/xao.vcf.gz
# split_chr3_xao
# ../split_chr3/xap.vcf.gz
# split_chr3_xap
# ../split_chr3/xaq.vcf.gz
# split_chr3_xaq
# ../split_chr3/xar.vcf.gz
# split_chr3_xar
# ../split_chr3/xas.vcf.gz
# split_chr3_xas
# ../split_chr3/xat.vcf.gz
# split_chr3_xat
# ../split_chr3/xau.vcf.gz
# split_chr3_xau
# ../split_chr3/xbg.vcf.gz
# split_chr3_xbg
# ../split_chr3/xbh.vcf.gz
# split_chr3_xbh
# ../split_chr3/xbi.vcf.gz
# split_chr3_xbi
# ../split_chr3/xbj.vcf.gz
# split_chr3_xbj
# ../split_chr3/xbk.vcf.gz
# split_chr3_xbk
# ../split_chr3/xbl.vcf.gz
# split_chr3_xbl
# ../split_chr3/xbm.vcf.gz
# split_chr3_xbm
# ../split_chr3/xbn.vcf.gz
# split_chr3_xbn
# ../split_chr3/xbo.vcf.gz
# split_chr3_xbo
# ../split_chr3/xbp.vcf.gz
# split_chr3_xbp
# ../split_chr3/xbq.vcf.gz
# split_chr3_xbq
# ../split_chr3/xbr.vcf.gz
# split_chr3_xbr
# ../split_chr4/xaa.vcf.gz
# split_chr4_xaa
# ../split_chr4/xab.vcf.gz
# split_chr4_xab
# ../split_chr4/xac.vcf.gz
# split_chr4_xac
# ../split_chr4/xad.vcf.gz
# split_chr4_xad
# ../split_chr4/xae.vcf.gz
# split_chr4_xae
# ../split_chr4/xaf.vcf.gz
# split_chr4_xaf
# ../split_chr4/xag.vcf.gz
# split_chr4_xag
# ../split_chr4/xah.vcf.gz
# split_chr4_xah
# ../split_chr4/xai.vcf.gz
# split_chr4_xai
# ../split_chr4/xaj.vcf.gz
# split_chr4_xaj
# ../split_chr4/xak.vcf.gz
# split_chr4_xak
# ../split_chr4/xal.vcf.gz
# split_chr4_xal
# ../split_chr4/xam.vcf.gz
# split_chr4_xam
# ../split_chr4/xan.vcf.gz
# split_chr4_xan
# ../split_chr4/xao.vcf.gz
# split_chr4_xao
# ../split_chr4/xap.vcf.gz
# split_chr4_xap
# ../split_chr4/xaq.vcf.gz
# split_chr4_xaq
# ../split_chr4/xar.vcf.gz
# split_chr4_xar
# ../split_chr4/xas.vcf.gz
# split_chr4_xas
# ../split_chr4/xat.vcf.gz
# split_chr4_xat
# ../split_chr4/xau.vcf.gz
# split_chr4_xau
# ../split_chr4/xav.vcf.gz
# split_chr4_xav
# ../split_chr4/xaw.vcf.gz
# split_chr4_xaw
# ../split_chr4/xax.vcf.gz
# split_chr4_xax
# ../split_chr4/xay.vcf.gz
# split_chr4_xay
# ../split_chr4/xaz.vcf.gz
# split_chr4_xaz
# ../split_chr4/xba.vcf.gz
# split_chr4_xba
# ../split_chr4/xbb.vcf.gz
# split_chr4_xbb
# ../split_chr4/xbc.vcf.gz
# split_chr4_xbc
# ../split_chr4/xbd.vcf.gz
# split_chr4_xbd
# ../split_chr4/xbe.vcf.gz
# split_chr4_xbe
# ../split_chr4/xbf.vcf.gz
# split_chr4_xbf
# ../split_chr4/xbg.vcf.gz
# split_chr4_xbg
# ../split_chr4/xbh.vcf.gz
# split_chr4_xbh
# ../split_chr4/xbi.vcf.gz
# split_chr4_xbi
# ../split_chr4/xbj.vcf.gz
# split_chr4_xbj
# ../split_chr4/xbk.vcf.gz
# split_chr4_xbk
# ../split_chr4/xbl.vcf.gz
# split_chr4_xbl
# ../split_chr4/xbm.vcf.gz
# split_chr4_xbm
# ../split_chr4/xbn.vcf.gz
# split_chr4_xbn
# ../split_chr4/xbo.vcf.gz
# split_chr4_xbo
# ../split_chr4/xbp.vcf.gz
# split_chr4_xbp
# ../split_chr4/xbq.vcf.gz
# split_chr4_xbq
# ../split_chr5/xbc.vcf.gz
# split_chr5_xbc
# ../split_chr5/xaa.vcf.gz
# split_chr5_xaa
# ../split_chr5/xab.vcf.gz
# split_chr5_xab
# ../split_chr5/xac.vcf.gz
# split_chr5_xac
# ../split_chr5/xad.vcf.gz
# split_chr5_xad
# ../split_chr5/xae.vcf.gz
# split_chr5_xae
# ../split_chr5/xaf.vcf.gz
# split_chr5_xaf
# ../split_chr5/xag.vcf.gz
# split_chr5_xag
# ../split_chr5/xah.vcf.gz
# split_chr5_xah
# ../split_chr5/xai.vcf.gz
# split_chr5_xai
# ../split_chr5/xaj.vcf.gz
# split_chr5_xaj
# ../split_chr5/xak.vcf.gz
# split_chr5_xak
# ../split_chr5/xal.vcf.gz
# split_chr5_xal
# ../split_chr5/xam.vcf.gz
# split_chr5_xam
# ../split_chr5/xan.vcf.gz
# split_chr5_xan
# ../split_chr5/xao.vcf.gz
# split_chr5_xao
# ../split_chr5/xap.vcf.gz
# split_chr5_xap
# ../split_chr5/xaq.vcf.gz
# split_chr5_xaq
# ../split_chr5/xar.vcf.gz
# split_chr5_xar
# ../split_chr5/xas.vcf.gz
# split_chr5_xas
# ../split_chr5/xat.vcf.gz
# split_chr5_xat
# ../split_chr5/xau.vcf.gz
# split_chr5_xau
# ../split_chr5/xav.vcf.gz
# split_chr5_xav
# ../split_chr5/xaw.vcf.gz
# split_chr5_xaw
# ../split_chr5/xax.vcf.gz
# split_chr5_xax
# ../split_chr5/xay.vcf.gz
# split_chr5_xay
# ../split_chr5/xaz.vcf.gz
# split_chr5_xaz
# ../split_chr5/xba.vcf.gz
# split_chr5_xba
# ../split_chr5/xbb.vcf.gz
# split_chr5_xbb
# ../split_chr5/xbd.vcf.gz
# split_chr5_xbd
# ../split_chr5/xbe.vcf.gz
# split_chr5_xbe
# ../split_chr5/xbf.vcf.gz
# split_chr5_xbf
# ../split_chr5/xbg.vcf.gz
# split_chr5_xbg
# ../split_chr5/xbh.vcf.gz
# split_chr5_xbh
# ../split_chr5/xbi.vcf.gz
# split_chr5_xbi
# ../split_chr5/xbj.vcf.gz
# split_chr5_xbj
# ../split_chr5/xbk.vcf.gz
# split_chr5_xbk
# ../split_chr5/xbl.vcf.gz
# split_chr5_xbl
# ../split_chr5/xbm.vcf.gz
# split_chr5_xbm
# ../split_chr5/xbn.vcf.gz
# split_chr5_xbn
# ../split_chr6/xat.vcf.gz
# split_chr6_xat
# ../split_chr6/xaa.vcf.gz
# split_chr6_xaa
# ../split_chr6/xab.vcf.gz
# split_chr6_xab
# ../split_chr6/xac.vcf.gz
# split_chr6_xac
# ../split_chr6/xad.vcf.gz
# split_chr6_xad
# ../split_chr6/xae.vcf.gz
# split_chr6_xae
# ../split_chr6/xaf.vcf.gz
# split_chr6_xaf
# ../split_chr6/xai.vcf.gz
# split_chr6_xai
# ../split_chr6/xaj.vcf.gz
# split_chr6_xaj
# ../split_chr6/xak.vcf.gz
# split_chr6_xak
# ../split_chr6/xal.vcf.gz
# split_chr6_xal
# ../split_chr6/xam.vcf.gz
# split_chr6_xam
# ../split_chr6/xan.vcf.gz
# split_chr6_xan
# ../split_chr6/xao.vcf.gz
# split_chr6_xao
# ../split_chr6/xap.vcf.gz
# split_chr6_xap
# ../split_chr6/xaq.vcf.gz
# split_chr6_xaq
# ../split_chr6/xar.vcf.gz
# split_chr6_xar
# ../split_chr6/xas.vcf.gz
# split_chr6_xas
# ../split_chr6/xau.vcf.gz
# split_chr6_xau
# ../split_chr6/xav.vcf.gz
# split_chr6_xav
# ../split_chr6/xaw.vcf.gz
# split_chr6_xaw
# ../split_chr6/xax.vcf.gz
# split_chr6_xax
# ../split_chr6/xay.vcf.gz
# split_chr6_xay
# ../split_chr6/xaz.vcf.gz
# split_chr6_xaz
# ../split_chr6/xba.vcf.gz
# split_chr6_xba
# ../split_chr6/xbb.vcf.gz
# split_chr6_xbb
# ../split_chr6/xbc.vcf.gz
# split_chr6_xbc
# ../split_chr6/xbd.vcf.gz
# split_chr6_xbd
# ../split_chr6/xbe.vcf.gz
# split_chr6_xbe
# ../split_chr6/xbf.vcf.gz
# split_chr6_xbf
# ../split_chr6/xbg.vcf.gz
# split_chr6_xbg
# ../split_chr6/xbh.vcf.gz
# split_chr6_xbh
# ../split_chr6/xbi.vcf.gz
# split_chr6_xbi
# ../split_chr6/xbj.vcf.gz
# split_chr6_xbj
# ../split_chr6/xbk.vcf.gz
# split_chr6_xbk
# ../split_chr6/xbl.vcf.gz
# split_chr6_xbl
# ../split_chr7/xay.vcf.gz
# split_chr7_xay
# ../split_chr7/xaa.vcf.gz
# split_chr7_xaa
# ../split_chr7/xab.vcf.gz
# split_chr7_xab
# ../split_chr7/xac.vcf.gz
# split_chr7_xac
# ../split_chr7/xad.vcf.gz
# split_chr7_xad
# ../split_chr7/xae.vcf.gz
# split_chr7_xae
# ../split_chr7/xaf.vcf.gz
# split_chr7_xaf
# ../split_chr7/xag.vcf.gz
# split_chr7_xag
# ../split_chr7/xah.vcf.gz
# split_chr7_xah
# ../split_chr7/xai.vcf.gz
# split_chr7_xai
# ../split_chr7/xaj.vcf.gz
# split_chr7_xaj
# ../split_chr7/xak.vcf.gz
# split_chr7_xak
# ../split_chr7/xal.vcf.gz
# split_chr7_xal
# ../split_chr7/xam.vcf.gz
# split_chr7_xam
# ../split_chr7/xan.vcf.gz
# split_chr7_xan
# ../split_chr7/xao.vcf.gz
# split_chr7_xao
# ../split_chr7/xap.vcf.gz
# split_chr7_xap
# ../split_chr7/xaq.vcf.gz
# split_chr7_xaq
# ../split_chr7/xar.vcf.gz
# split_chr7_xar
# ../split_chr7/xas.vcf.gz
# split_chr7_xas
# ../split_chr7/xat.vcf.gz
# split_chr7_xat
# ../split_chr7/xau.vcf.gz
# split_chr7_xau
# ../split_chr7/xav.vcf.gz
# split_chr7_xav
# ../split_chr7/xaw.vcf.gz
# split_chr7_xaw
# ../split_chr7/xax.vcf.gz
# split_chr7_xax
# ../split_chr7/xaz.vcf.gz
# split_chr7_xaz
# ../split_chr7/xba.vcf.gz
# split_chr7_xba
# ../split_chr7/xbb.vcf.gz
# split_chr7_xbb
# ../split_chr7/xbc.vcf.gz
# split_chr7_xbc
# ../split_chr7/xbd.vcf.gz
# split_chr7_xbd
# ../split_chr7/xbe.vcf.gz
# split_chr7_xbe
# ../split_chr7/xbf.vcf.gz
# split_chr7_xbf
# ../split_chr7/xbg.vcf.gz
# split_chr7_xbg
# ../split_chr7/xbh.vcf.gz
# split_chr7_xbh
# ../split_chr7/xbi.vcf.gz
# split_chr7_xbi
# ../split_chr7/xbj.vcf.gz
# split_chr7_xbj
# ../split_chr8/xaw.vcf.gz
# split_chr8_xaw
# ../split_chr8/xaa.vcf.gz
# split_chr8_xaa
# ../split_chr8/xab.vcf.gz
# split_chr8_xab
# ../split_chr8/xac.vcf.gz
# split_chr8_xac
# ../split_chr8/xad.vcf.gz
# split_chr8_xad
# ../split_chr8/xae.vcf.gz
# split_chr8_xae
# ../split_chr8/xaf.vcf.gz
# split_chr8_xaf
# ../split_chr8/xag.vcf.gz
# split_chr8_xag
# ../split_chr8/xah.vcf.gz
# split_chr8_xah
# ../split_chr8/xai.vcf.gz
# split_chr8_xai
# ../split_chr8/xaj.vcf.gz
# split_chr8_xaj
# ../split_chr8/xak.vcf.gz
# split_chr8_xak
# ../split_chr8/xal.vcf.gz
# split_chr8_xal
# ../split_chr8/xam.vcf.gz
# split_chr8_xam
# ../split_chr8/xan.vcf.gz
# split_chr8_xan
# ../split_chr8/xao.vcf.gz
# split_chr8_xao
# ../split_chr8/xap.vcf.gz
# split_chr8_xap
# ../split_chr8/xaq.vcf.gz
# split_chr8_xaq
# ../split_chr8/xar.vcf.gz
# split_chr8_xar
# ../split_chr8/xas.vcf.gz
# split_chr8_xas
# ../split_chr8/xat.vcf.gz
# split_chr8_xat
# ../split_chr8/xau.vcf.gz
# split_chr8_xau
# ../split_chr8/xav.vcf.gz
# split_chr8_xav
# ../split_chr8/xax.vcf.gz
# split_chr8_xax
# ../split_chr8/xay.vcf.gz
# split_chr8_xay
# ../split_chr8/xaz.vcf.gz
# split_chr8_xaz
# ../split_chr8/xba.vcf.gz
# split_chr8_xba
# ../split_chr8/xbb.vcf.gz
# split_chr8_xbb
# ../split_chr8/xbc.vcf.gz
# split_chr8_xbc
# ../split_chr8/xbd.vcf.gz
# split_chr8_xbd
# ../split_chr8/xbe.vcf.gz
# split_chr8_xbe
# ../split_chr8/xbf.vcf.gz
# split_chr8_xbf
# ../split_chr8/xbg.vcf.gz
# split_chr8_xbg
# ../split_chr8/xbh.vcf.gz
# split_chr8_xbh
# ../split_chr9/xak.vcf.gz
# split_chr9_xak
# ../split_chr9/xaa.vcf.gz
# split_chr9_xaa
# ../split_chr9/xab.vcf.gz
# split_chr9_xab
# ../split_chr9/xac.vcf.gz
# split_chr9_xac
# ../split_chr9/xad.vcf.gz
# split_chr9_xad
# ../split_chr9/xae.vcf.gz
# split_chr9_xae
# ../split_chr9/xaf.vcf.gz
# split_chr9_xaf
# ../split_chr9/xag.vcf.gz
# split_chr9_xag
# ../split_chr9/xah.vcf.gz
# split_chr9_xah
# ../split_chr9/xai.vcf.gz
# split_chr9_xai
# ../split_chr9/xaj.vcf.gz
# split_chr9_xaj
# ../split_chr9/xal.vcf.gz
# split_chr9_xal
# ../split_chr9/xam.vcf.gz
# split_chr9_xam
# ../split_chr9/xan.vcf.gz
# split_chr9_xan
# ../split_chr9/xao.vcf.gz
# split_chr9_xao
# ../split_chr9/xap.vcf.gz
# split_chr9_xap
# ../split_chr9/xaq.vcf.gz
# split_chr9_xaq
# ../split_chr9/xar.vcf.gz
# split_chr9_xar
# ../split_chr9/xas.vcf.gz
# split_chr9_xas
# ../split_chr9/xat.vcf.gz
# split_chr9_xat
# ../split_chr9/xau.vcf.gz
# split_chr9_xau
# ../split_chr9/xav.vcf.gz
# split_chr9_xav
# ../split_chr9/xaw.vcf.gz
# split_chr9_xaw
# ../split_chr9/xax.vcf.gz
# split_chr9_xax
# ../split_chr9/xay.vcf.gz
# split_chr9_xay
# ../split_chr9/xaz.vcf.gz
# split_chr9_xaz
# ../split_chr9/xba.vcf.gz
# split_chr9_xba
# ../split_chr9/xbb.vcf.gz
# split_chr9_xbb
# ../split_chr10/xak.vcf.gz
# split_chr10_xak
# ../split_chr10/xaa.vcf.gz
# split_chr10_xaa
# ../split_chr10/xab.vcf.gz
# split_chr10_xab
# ../split_chr10/xac.vcf.gz
# split_chr10_xac
# ../split_chr10/xad.vcf.gz
# split_chr10_xad
# ../split_chr10/xae.vcf.gz
# split_chr10_xae
# ../split_chr10/xaf.vcf.gz
# split_chr10_xaf
# ../split_chr10/xag.vcf.gz
# split_chr10_xag
# ../split_chr10/xah.vcf.gz
# split_chr10_xah
# ../split_chr10/xai.vcf.gz
# split_chr10_xai
# ../split_chr10/xaj.vcf.gz
# split_chr10_xaj
# ../split_chr10/xal.vcf.gz
# split_chr10_xal
# ../split_chr10/xam.vcf.gz
# split_chr10_xam
# ../split_chr10/xan.vcf.gz
# split_chr10_xan
# ../split_chr10/xao.vcf.gz
# split_chr10_xao
# ../split_chr10/xap.vcf.gz
# split_chr10_xap
# ../split_chr10/xaq.vcf.gz
# split_chr10_xaq
# ../split_chr10/xar.vcf.gz
# split_chr10_xar
# ../split_chr10/xas.vcf.gz
# split_chr10_xas
# ../split_chr10/xat.vcf.gz
# split_chr10_xat
# ../split_chr10/xau.vcf.gz
# split_chr10_xau
# ../split_chr10/xav.vcf.gz
# split_chr10_xav
# ../split_chr10/xaw.vcf.gz
# split_chr10_xaw
# ../split_chr10/xax.vcf.gz
# split_chr10_xax
# ../split_chr10/xay.vcf.gz
# split_chr10_xay
# ../split_chr10/xaz.vcf.gz
# split_chr10_xaz
# ../split_chr10/xba.vcf.gz
# split_chr10_xba
# ../split_chr10/xbb.vcf.gz
# split_chr10_xbb
# ../split_chr10/xbc.vcf.gz
# split_chr10_xbc
# ../split_chr10/xbd.vcf.gz
# split_chr10_xbd
# ../split_chr10/xbe.vcf.gz
# split_chr10_xbe
# ../split_chr11/xak.vcf.gz
# split_chr11_xak
# ../split_chr11/xaa.vcf.gz
# split_chr11_xaa
# ../split_chr11/xab.vcf.gz
# split_chr11_xab
# ../split_chr11/xac.vcf.gz
# split_chr11_xac
# ../split_chr11/xad.vcf.gz
# split_chr11_xad
# ../split_chr11/xae.vcf.gz
# split_chr11_xae
# ../split_chr11/xaf.vcf.gz
# split_chr11_xaf
# ../split_chr11/xag.vcf.gz
# split_chr11_xag
# ../split_chr11/xah.vcf.gz
# split_chr11_xah
# ../split_chr11/xai.vcf.gz
# split_chr11_xai
# ../split_chr11/xaj.vcf.gz
# split_chr11_xaj
# ../split_chr11/xal.vcf.gz
# split_chr11_xal
# ../split_chr11/xam.vcf.gz
# split_chr11_xam
# ../split_chr11/xan.vcf.gz
# split_chr11_xan
# ../split_chr11/xao.vcf.gz
# split_chr11_xao
# ../split_chr11/xap.vcf.gz
# split_chr11_xap
# ../split_chr11/xaq.vcf.gz
# split_chr11_xaq
# ../split_chr11/xar.vcf.gz
# split_chr11_xar
# ../split_chr11/xas.vcf.gz
# split_chr11_xas
# ../split_chr11/xat.vcf.gz
# split_chr11_xat
# ../split_chr11/xau.vcf.gz
# split_chr11_xau
# ../split_chr11/xav.vcf.gz
# split_chr11_xav
# ../split_chr11/xaw.vcf.gz
# split_chr11_xaw
# ../split_chr11/xax.vcf.gz
# split_chr11_xax
# ../split_chr11/xay.vcf.gz
# split_chr11_xay
# ../split_chr11/xaz.vcf.gz
# split_chr11_xaz
# ../split_chr11/xba.vcf.gz
# split_chr11_xba
# ../split_chr11/xbb.vcf.gz
# split_chr11_xbb
# ../split_chr11/xbc.vcf.gz
# split_chr11_xbc
# ../split_chr11/xbd.vcf.gz
# split_chr11_xbd
# ../split_chr12/xak.vcf.gz
# split_chr12_xak
# ../split_chr12/xaa.vcf.gz
# split_chr12_xaa
# ../split_chr12/xab.vcf.gz
# split_chr12_xab
# ../split_chr12/xac.vcf.gz
# split_chr12_xac
# ../split_chr12/xad.vcf.gz
# split_chr12_xad
# ../split_chr12/xae.vcf.gz
# split_chr12_xae
# ../split_chr12/xaf.vcf.gz
# split_chr12_xaf
# ../split_chr12/xag.vcf.gz
# split_chr12_xag
# ../split_chr12/xah.vcf.gz
# split_chr12_xah
# ../split_chr12/xai.vcf.gz
# split_chr12_xai
# ../split_chr12/xaj.vcf.gz
# split_chr12_xaj
# ../split_chr12/xal.vcf.gz
# split_chr12_xal
# ../split_chr12/xam.vcf.gz
# split_chr12_xam
# ../split_chr12/xan.vcf.gz
# split_chr12_xan
# ../split_chr12/xao.vcf.gz
# split_chr12_xao
# ../split_chr12/xap.vcf.gz
# split_chr12_xap
# ../split_chr12/xaq.vcf.gz
# split_chr12_xaq
# ../split_chr12/xar.vcf.gz
# split_chr12_xar
# ../split_chr12/xas.vcf.gz
# split_chr12_xas
# ../split_chr12/xat.vcf.gz
# split_chr12_xat
# ../split_chr12/xau.vcf.gz
# split_chr12_xau
# ../split_chr12/xav.vcf.gz
# split_chr12_xav
# ../split_chr12/xaw.vcf.gz
# split_chr12_xaw
# ../split_chr12/xax.vcf.gz
# split_chr12_xax
# ../split_chr12/xay.vcf.gz
# split_chr12_xay
# ../split_chr12/xaz.vcf.gz
# split_chr12_xaz
# ../split_chr12/xba.vcf.gz
# split_chr12_xba
# ../split_chr12/xbb.vcf.gz
# split_chr12_xbb
# ../split_chr12/xbc.vcf.gz
# split_chr12_xbc
# ../split_chr13/xak.vcf.gz
# split_chr13_xak
# ../split_chr13/xaa.vcf.gz
# split_chr13_xaa
# ../split_chr13/xab.vcf.gz
# split_chr13_xab
# ../split_chr13/xac.vcf.gz
# split_chr13_xac
# ../split_chr13/xad.vcf.gz
# split_chr13_xad
# ../split_chr13/xae.vcf.gz
# split_chr13_xae
# ../split_chr13/xaf.vcf.gz
# split_chr13_xaf
# ../split_chr13/xag.vcf.gz
# split_chr13_xag
# ../split_chr13/xah.vcf.gz
# split_chr13_xah
# ../split_chr13/xai.vcf.gz
# split_chr13_xai
# ../split_chr13/xaj.vcf.gz
# split_chr13_xaj
# ../split_chr13/xal.vcf.gz
# split_chr13_xal
# ../split_chr13/xam.vcf.gz
# split_chr13_xam
# ../split_chr13/xan.vcf.gz
# split_chr13_xan
# ../split_chr13/xao.vcf.gz
# split_chr13_xao
# ../split_chr13/xap.vcf.gz
# split_chr13_xap
# ../split_chr13/xaq.vcf.gz
# split_chr13_xaq
# ../split_chr13/xar.vcf.gz
# split_chr13_xar
# ../split_chr13/xas.vcf.gz
# split_chr13_xas
# ../split_chr13/xat.vcf.gz
# split_chr13_xat
# ../split_chr13/xau.vcf.gz
# split_chr13_xau
# ../split_chr13/xav.vcf.gz
# split_chr13_xav
# ../split_chr14/xaa.vcf.gz
# split_chr14_xaa
# ../split_chr14/xab.vcf.gz
# split_chr14_xab
# ../split_chr14/xac.vcf.gz
# split_chr14_xac
# ../split_chr14/xad.vcf.gz
# split_chr14_xad
# ../split_chr14/xae.vcf.gz
# split_chr14_xae
# ../split_chr14/xaf.vcf.gz
# split_chr14_xaf
# ../split_chr14/xag.vcf.gz
# split_chr14_xag
# ../split_chr14/xah.vcf.gz
# split_chr14_xah
# ../split_chr14/xai.vcf.gz
# split_chr14_xai
# ../split_chr14/xaj.vcf.gz
# split_chr14_xaj
# ../split_chr14/xak.vcf.gz
# split_chr14_xak
# ../split_chr14/xal.vcf.gz
# split_chr14_xal
# ../split_chr14/xam.vcf.gz
# split_chr14_xam
# ../split_chr14/xan.vcf.gz
# split_chr14_xan
# ../split_chr14/xao.vcf.gz
# split_chr14_xao
# ../split_chr14/xap.vcf.gz
# split_chr14_xap
# ../split_chr14/xaq.vcf.gz
# split_chr14_xaq
# ../split_chr14/xar.vcf.gz
# split_chr14_xar
# ../split_chr14/xas.vcf.gz
# split_chr14_xas
# ../split_chr14/xat.vcf.gz
# split_chr14_xat
# ../split_chr15/xaa.vcf.gz
# split_chr15_xaa
# ../split_chr15/xab.vcf.gz
# split_chr15_xab
# ../split_chr15/xac.vcf.gz
# split_chr15_xac
# ../split_chr15/xad.vcf.gz
# split_chr15_xad
# ../split_chr15/xae.vcf.gz
# split_chr15_xae
# ../split_chr15/xaf.vcf.gz
# split_chr15_xaf
# ../split_chr15/xag.vcf.gz
# split_chr15_xag
# ../split_chr15/xah.vcf.gz
# split_chr15_xah
# ../split_chr15/xai.vcf.gz
# split_chr15_xai
# ../split_chr15/xaj.vcf.gz
# split_chr15_xaj
# ../split_chr15/xak.vcf.gz
# split_chr15_xak
# ../split_chr15/xal.vcf.gz
# split_chr15_xal
# ../split_chr15/xam.vcf.gz
# split_chr15_xam
# ../split_chr15/xan.vcf.gz
# split_chr15_xan
# ../split_chr15/xao.vcf.gz
# split_chr15_xao
# ../split_chr15/xap.vcf.gz
# split_chr15_xap
# ../split_chr15/xaq.vcf.gz
# split_chr15_xaq
# ../split_chr15/xar.vcf.gz
# split_chr15_xar
# ../split_chr15/xas.vcf.gz
# split_chr15_xas
# ../split_chr16/xaa.vcf.gz
# split_chr16_xaa
# ../split_chr16/xab.vcf.gz
# split_chr16_xab
# ../split_chr16/xac.vcf.gz
# split_chr16_xac
# ../split_chr16/xad.vcf.gz
# split_chr16_xad
# ../split_chr16/xae.vcf.gz
# split_chr16_xae
# ../split_chr16/xaf.vcf.gz
# split_chr16_xaf
# ../split_chr16/xag.vcf.gz
# split_chr16_xag
# ../split_chr16/xah.vcf.gz
# split_chr16_xah
# ../split_chr16/xai.vcf.gz
# split_chr16_xai
# ../split_chr16/xaj.vcf.gz
# split_chr16_xaj
# ../split_chr16/xak.vcf.gz
# split_chr16_xak
# ../split_chr16/xal.vcf.gz
# split_chr16_xal
# ../split_chr16/xam.vcf.gz
# split_chr16_xam
# ../split_chr16/xan.vcf.gz
# split_chr16_xan
# ../split_chr16/xao.vcf.gz
# split_chr16_xao
# ../split_chr16/xap.vcf.gz
# split_chr16_xap
# ../split_chr16/xaq.vcf.gz
# split_chr16_xaq
# ../split_chr16/xar.vcf.gz
# split_chr16_xar
# ../split_chr16/xas.vcf.gz
# split_chr16_xas
# ../split_chr16/xat.vcf.gz
# split_chr16_xat
# ../split_chr16/xau.vcf.gz
# split_chr16_xau
# ../split_chr17/xaa.vcf.gz
# split_chr17_xaa
# ../split_chr17/xab.vcf.gz
# split_chr17_xab
# ../split_chr17/xac.vcf.gz
# split_chr17_xac
# ../split_chr17/xad.vcf.gz
# split_chr17_xad
# ../split_chr17/xae.vcf.gz
# split_chr17_xae
# ../split_chr17/xaf.vcf.gz
# split_chr17_xaf
# ../split_chr17/xag.vcf.gz
# split_chr17_xag
# ../split_chr17/xah.vcf.gz
# split_chr17_xah
# ../split_chr17/xai.vcf.gz
# split_chr17_xai
# ../split_chr17/xaj.vcf.gz
# split_chr17_xaj
# ../split_chr17/xak.vcf.gz
# split_chr17_xak
# ../split_chr17/xal.vcf.gz
# split_chr17_xal
# ../split_chr17/xam.vcf.gz
# split_chr17_xam
# ../split_chr17/xan.vcf.gz
# split_chr17_xan
# ../split_chr17/xao.vcf.gz
# split_chr17_xao
# ../split_chr17/xap.vcf.gz
# split_chr17_xap
# ../split_chr17/xaq.vcf.gz
# split_chr17_xaq
# ../split_chr17/xar.vcf.gz
# split_chr17_xar
# ../split_chr17/xas.vcf.gz
# split_chr17_xas
# ../split_chr18/xaa.vcf.gz
# split_chr18_xaa
# ../split_chr18/xab.vcf.gz
# split_chr18_xab
# ../split_chr18/xac.vcf.gz
# split_chr18_xac
# ../split_chr18/xad.vcf.gz
# split_chr18_xad
# ../split_chr18/xae.vcf.gz
# split_chr18_xae
# ../split_chr18/xaf.vcf.gz
# split_chr18_xaf
# ../split_chr18/xag.vcf.gz
# split_chr18_xag
# ../split_chr18/xah.vcf.gz
# split_chr18_xah
# ../split_chr18/xai.vcf.gz
# split_chr18_xai
# ../split_chr18/xaj.vcf.gz
# split_chr18_xaj
# ../split_chr18/xak.vcf.gz
# split_chr18_xak
# ../split_chr18/xal.vcf.gz
# split_chr18_xal
# ../split_chr18/xam.vcf.gz
# split_chr18_xam
# ../split_chr18/xan.vcf.gz
# split_chr18_xan
# ../split_chr18/xao.vcf.gz
# split_chr18_xao
# ../split_chr18/xap.vcf.gz
# split_chr18_xap
# ../split_chr18/xaq.vcf.gz
# split_chr18_xaq
# ../split_chr18/xar.vcf.gz
# split_chr18_xar
# ../split_chr19/xaa.vcf.gz
# split_chr19_xaa
# ../split_chr19/xab.vcf.gz
# split_chr19_xab
# ../split_chr19/xac.vcf.gz
# split_chr19_xac
# ../split_chr19/xad.vcf.gz
# split_chr19_xad
# ../split_chr19/xae.vcf.gz
# split_chr19_xae
# ../split_chr19/xaf.vcf.gz
# split_chr19_xaf
# ../split_chr19/xag.vcf.gz
# split_chr19_xag
# ../split_chr19/xah.vcf.gz
# split_chr19_xah
# ../split_chr19/xai.vcf.gz
# split_chr19_xai
# ../split_chr19/xaj.vcf.gz
# split_chr19_xaj
# ../split_chr19/xak.vcf.gz
# split_chr19_xak
# ../split_chr19/xal.vcf.gz
# split_chr19_xal
# ../split_chr19/xam.vcf.gz
# split_chr19_xam
# ../split_chr19/xan.vcf.gz
# split_chr19_xan
# ../split_chr19/xao.vcf.gz
# split_chr19_xao
# ../split_chr20/xaa.vcf.gz
# split_chr20_xaa
# ../split_chr20/xab.vcf.gz
# split_chr20_xab
# ../split_chr20/xac.vcf.gz
# split_chr20_xac
# ../split_chr20/xad.vcf.gz
# split_chr20_xad
# ../split_chr20/xae.vcf.gz
# split_chr20_xae
# ../split_chr20/xaf.vcf.gz
# split_chr20_xaf
# ../split_chr20/xag.vcf.gz
# split_chr20_xag
# ../split_chr20/xah.vcf.gz
# split_chr20_xah
# ../split_chr20/xai.vcf.gz
# split_chr20_xai
# ../split_chr20/xaj.vcf.gz
# split_chr20_xaj
# ../split_chr20/xak.vcf.gz
# split_chr20_xak
# ../split_chr20/xal.vcf.gz
# split_chr20_xal
# ../split_chr20/xam.vcf.gz
# split_chr20_xam
# ../split_chr20/xan.vcf.gz
# split_chr20_xan
# ../split_chr20/xao.vcf.gz
# split_chr20_xao
# ../split_chr21/xaa.vcf.gz
# split_chr21_xaa
# ../split_chr21/xab.vcf.gz
# split_chr21_xab
# ../split_chr21/xac.vcf.gz
# split_chr21_xac
# ../split_chr21/xad.vcf.gz
# split_chr21_xad
# ../split_chr21/xae.vcf.gz
# split_chr21_xae
# ../split_chr21/xaf.vcf.gz
# split_chr21_xaf
# ../split_chr21/xag.vcf.gz
# split_chr21_xag
# ../split_chr21/xah.vcf.gz
# split_chr21_xah
# ../split_chr21/xai.vcf.gz
# split_chr21_xai
# ../split_chr22/xaa.vcf.gz
# split_chr22_xaa
# ../split_chr22/xab.vcf.gz
# split_chr22_xab
# ../split_chr22/xac.vcf.gz
# split_chr22_xac
# ../split_chr22/xad.vcf.gz
# split_chr22_xad
# ../split_chr22/xae.vcf.gz
# split_chr22_xae
# ../split_chr22/xaf.vcf.gz
# split_chr22_xaf
# ../split_chr22/xag.vcf.gz
# split_chr22_xag
# ../split_chr22/xah.vcf.gz
# split_chr22_xah
# ../split_chr22/xai.vcf.gz
# split_chr22_xai
# ../split_chr22/xaj.vcf.gz
# split_chr22_xaj

# %%
vcf_in=vcf("../mhcdataset/1kgp.29720000-33130000.vcf","r")
# vcf_in=vcf(path,"r")
testclass=CalProb(vcf_in=vcf_in)
testclass.__runProb__()
df_pos_prob=testclass.df_pos_prob(pos_prob_csvname="mhc")
# testclass.Graph_pos_prob(df=df_pos_prob,pos_probgraphname=pos_prob_name)
df_index_prob=testclass.df_index_prob(index_prob_csvname="mhc")
